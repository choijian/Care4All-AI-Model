# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
cd /content/drive/MyDrive/comma_ai_dev/Probono-AI-Model/preprocessed_data
# Out:
# /content/drive/MyDrive/comma_ai_dev/Probono-AI-Model/preprocessed_data

# %%
df = pd.read_csv('Jingwan_pop_data.csv', index_col='Datetime', parse_dates=True)

# %%
df.describe()
# Out:
#          population
# count   8760.000000
# mean   58808.003319
# std     3505.445556
# min    47858.732600
# 25%    55635.039075
# 50%    59718.169600
# 75%    61719.532050
# max    67172.748400

# %%
from sklearn.preprocessing import MinMaxScaler
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
len_month = 744 #한달치 데이터 길이
len_week = 168 #일주일치 데이터 길이
len_day = 24 #하루치 데이터 길이

# %%
len(df)
# Out:
# 8760

# %%
train = df.iloc[:-len_month]  #test 데이터셋:8016
test = df.iloc[-len_month:] #train 데이터셋: 744 (한달치 data)

# %%
 #데이터 scaling
scaler = MinMaxScaler()
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
pd.DataFrame(scaled_train, index = train.index, columns=train.columns)
# Out:
#                      population
# Datetime
# 2022-09-01 00:00:00    0.938861
# 2022-09-01 01:00:00    0.934389
# 2022-09-01 02:00:00    0.932989
# 2022-09-01 03:00:00    0.935243
# 2022-09-01 04:00:00    0.924559
# ...                         ...
# 2023-07-31 19:00:00    0.417157
# 2023-07-31 20:00:00    0.447138
# 2023-07-31 21:00:00    0.457643
# 2023-07-31 22:00:00    0.470637
# 2023-07-31 23:00:00    0.556055
#
# [8016 rows x 1 columns]

# %%
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
scaled_train = scaled_train.reshape(-1)
scaled_test = scaled_test.reshape(-1)
print(scaled_train.shape)
print(scaled_test.shape)
# Out:
# (8016,)
# (744,)

# %%
n_steps = len_day #일주일치 데이터
n_features = 1  #단변량 데이터

x_train, y_train = split_sequence(scaled_train, n_steps) #x_train = (7848,168), y_train = (7848,1)
x_test, y_test = split_sequence(scaled_test, n_steps) #x_test = (576,168), y_test = (576,1)
print(len(x_train), len(y_train))
print(len(x_test), len(y_test))
# Out:
# 7992 7992
# 720 720

# %%
pd.DataFrame(x_train.T,
             index = [f'day{x+1}' for x in range(x_train.shape[1])],
             columns = [f'input_{x+1}' for x in range(x_train.shape[0])])
# Out:
#         input_1   input_2   input_3   input_4   input_5   input_6   input_7  \
# day1   0.938861  0.934389  0.932989  0.935243  0.924559  0.963710  0.973020
# day2   0.934389  0.932989  0.935243  0.924559  0.963710  0.973020  0.952760
# day3   0.932989  0.935243  0.924559  0.963710  0.973020  0.952760  0.678101
# day4   0.935243  0.924559  0.963710  0.973020  0.952760  0.678101  0.548739
# day5   0.924559  0.963710  0.973020  0.952760  0.678101  0.548739  0.468141
# day6   0.963710  0.973020  0.952760  0.678101  0.548739  0.468141  0.452822
# day7   0.973020  0.952760  0.678101  0.548739  0.468141  0.452822  0.414013
# day8   0.952760  0.678101  0.548739  0.468141  0.452822  0.414013  0.420620
# day9   0.678101  0.548739  0.468141  0.452822  0.414013  0.420620  0.449138
# day10  0.548739  0.468141  0.452822  0.414013  0.420620  0.449138  0.433573
# day11  0.468141  0.452822  0.414013  0.420620  0.449138  0.433573  0.433308
# day12  0.452822  0.414013  0.420620  0.449138  0.433573  0.433308  0.445781
# day13  0.414013  0.420620  0.449138  0.433573  0.433308  0.445781  0.609319
# day14  0.420620  0.449138  0.433573  0.433308  0.445781  0.609319  0.655820
# day15  0.449138  0.433573  0.433308  0.445781  0.609319  0.655820  0.738162
# day16  0.433573  0.433308  0.445781  0.609319  0.655820  0.738162  0.791904
# day17  0.433308  0.445781  0.609319  0.655820  0.738162  0.791904  0.849419
# day18  0.445781  0.609319  0.655820  0.738162  0.791904  0.849419  0.913490
# day19  0.609319  0.655820  0.738162  0.791904  0.849419  0.913490  0.929258
# day20  0.655820  0.738162  0.791904  0.849419  0.913490  0.929258  0.923441
# day21  0.738162  0.791904  0.849419  0.913490  0.929258  0.923441  0.920002
# day22  0.791904  0.849419  0.913490  0.929258  0.923441  0.920002  0.925895
# day23  0.849419  0.913490  0.929258  0.923441  0.920002  0.925895  0.917662
# day24  0.913490  0.929258  0.923441  0.920002  0.925895  0.917662  0.966613
#
#         input_8   input_9  input_10  ...  input_7983  input_7984  input_7985  \
# day1   0.952760  0.678101  0.548739  ...    0.745925    0.708767    0.706719
# day2   0.678101  0.548739  0.468141  ...    0.708767    0.706719    0.669550
# day3   0.548739  0.468141  0.452822  ...    0.706719    0.669550    0.608377
# day4   0.468141  0.452822  0.414013  ...    0.669550    0.608377    0.515359
# day5   0.452822  0.414013  0.420620  ...    0.608377    0.515359    0.518019
# day6   0.414013  0.420620  0.449138  ...    0.515359    0.518019    0.501168
# day7   0.420620  0.449138  0.433573  ...    0.518019    0.501168    0.475142
# day8   0.449138  0.433573  0.433308  ...    0.501168    0.475142    0.585061
# day9   0.433573  0.433308  0.445781  ...    0.475142    0.585061    0.571244
# day10  0.433308  0.445781  0.609319  ...    0.585061    0.571244    0.572815
# day11  0.445781  0.609319  0.655820  ...    0.571244    0.572815    0.567633
# day12  0.609319  0.655820  0.738162  ...    0.572815    0.567633    0.564125
# day13  0.655820  0.738162  0.791904  ...    0.567633    0.564125    0.549215
# day14  0.738162  0.791904  0.849419  ...    0.564125    0.549215    0.565166
# day15  0.791904  0.849419  0.913490  ...    0.549215    0.565166    0.596979
# day16  0.849419  0.913490  0.929258  ...    0.565166    0.596979    0.577409
# day17  0.913490  0.929258  0.923441  ...    0.596979    0.577409    0.377388
# day18  0.929258  0.923441  0.920002  ...    0.577409    0.377388    0.278460
# day19  0.923441  0.920002  0.925895  ...    0.377388    0.278460    0.258814
# day20  0.920002  0.925895  0.917662  ...    0.278460    0.258814    0.229842
# day21  0.925895  0.917662  0.966613  ...    0.258814    0.229842    0.244825
# day22  0.917662  0.966613  0.983668  ...    0.229842    0.244825    0.296098
# day23  0.966613  0.983668  0.952554  ...    0.244825    0.296098    0.291285
# day24  0.983668  0.952554  0.696716  ...    0.296098    0.291285    0.272069
#
#        input_7986  input_7987  input_7988  input_7989  input_7990  input_7991  \
# day1     0.669550    0.608377    0.515359    0.518019    0.501168    0.475142
# day2     0.608377    0.515359    0.518019    0.501168    0.475142    0.585061
# day3     0.515359    0.518019    0.501168    0.475142    0.585061    0.571244
# day4     0.518019    0.501168    0.475142    0.585061    0.571244    0.572815
# day5     0.501168    0.475142    0.585061    0.571244    0.572815    0.567633
# day6     0.475142    0.585061    0.571244    0.572815    0.567633    0.564125
# day7     0.585061    0.571244    0.572815    0.567633    0.564125    0.549215
# day8     0.571244    0.572815    0.567633    0.564125    0.549215    0.565166
# day9     0.572815    0.567633    0.564125    0.549215    0.565166    0.596979
# day10    0.567633    0.564125    0.549215    0.565166    0.596979    0.577409
# day11    0.564125    0.549215    0.565166    0.596979    0.577409    0.377388
# day12    0.549215    0.565166    0.596979    0.577409    0.377388    0.278460
# day13    0.565166    0.596979    0.577409    0.377388    0.278460    0.258814
# day14    0.596979    0.577409    0.377388    0.278460    0.258814    0.229842
# day15    0.577409    0.377388    0.278460    0.258814    0.229842    0.244825
# day16    0.377388    0.278460    0.258814    0.229842    0.244825    0.296098
# day17    0.278460    0.258814    0.229842    0.244825    0.296098    0.291285
# day18    0.258814    0.229842    0.244825    0.296098    0.291285    0.272069
# day19    0.229842    0.244825    0.296098    0.291285    0.272069    0.220652
# day20    0.244825    0.296098    0.291285    0.272069    0.220652    0.213197
# day21    0.296098    0.291285    0.272069    0.220652    0.213197    0.335216
# day22    0.291285    0.272069    0.220652    0.213197    0.335216    0.417157
# day23    0.272069    0.220652    0.213197    0.335216    0.417157    0.447138
# day24    0.220652    0.213197    0.335216    0.417157    0.447138    0.457643
#
#        input_7992
# day1     0.585061
# day2     0.571244
# day3     0.572815
# day4     0.567633
# day5     0.564125
# day6     0.549215
# day7     0.565166
# day8     0.596979
# day9     0.577409
# day10    0.377388
# day11    0.278460
# day12    0.258814
# day13    0.229842
# day14    0.244825
# day15    0.296098
# day16    0.291285
# day17    0.272069
# day18    0.220652
# day19    0.213197
# day20    0.335216
# day21    0.417157
# day22    0.447138
# day23    0.457643
# day24    0.470637
#
# [24 rows x 7992 columns]

# %%
pd.DataFrame(y_train.T,
             index = [f'output_{x+1}' for x in range(y_train.shape[0])],
             columns = [f'day1'])
# Out:
#                  day1
# output_1     0.929258
# output_2     0.923441
# output_3     0.920002
# output_4     0.925895
# output_5     0.917662
# ...               ...
# output_7988  0.417157
# output_7989  0.447138
# output_7990  0.457643
# output_7991  0.470637
# output_7992  0.556055
#
# [7992 rows x 1 columns]

# %%
model = Sequential()

model.add(LSTM(128, activation='relu', return_sequences=True, input_shape=(n_steps,n_features))) #first layer
model.add(Dropout(0.5))

model.add(LSTM(units = 64)) #second layer
model.add(Dropout(0.5))

model.add(Dense(1)) #output layer

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 128)           66560
#
#  dropout (Dropout)           (None, 24, 128)           0
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 116,033
# Trainable params: 116,033
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='loss', patience=5, restore_best_weights=True)
#모델의 val_loss가 10epoch 동안 동일하면 학습을 중단

history = model.fit(x_train, y_train, epochs=30, callbacks=[early_stopping])
# Out:
# Epoch 1/30
# 250/250 [==============================] - 24s 56ms/step - loss: 0.0335 - mae: 0.1422
# Epoch 2/30
# 250/250 [==============================] - 14s 54ms/step - loss: 0.0140 - mae: 0.0933
# Epoch 3/30
# 250/250 [==============================] - 13s 50ms/step - loss: 0.0109 - mae: 0.0817
# Epoch 4/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0094 - mae: 0.0760
# Epoch 5/30
# 250/250 [==============================] - 13s 50ms/step - loss: 0.0087 - mae: 0.0723
# Epoch 6/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0075 - mae: 0.0671
# Epoch 7/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0068 - mae: 0.0635
# Epoch 8/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0063 - mae: 0.0612
# Epoch 9/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0055 - mae: 0.0568
# Epoch 10/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0050 - mae: 0.0541
# Epoch 11/30
# 250/250 [==============================] - 13s 54ms/step - loss: 0.0045 - mae: 0.0511
# Epoch 12/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0041 - mae: 0.0485
# Epoch 13/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0038 - mae: 0.0469
# Epoch 14/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0036 - mae: 0.0450
# Epoch 15/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0034 - mae: 0.0435
# Epoch 16/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0033 - mae: 0.0425
# Epoch 17/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0031 - mae: 0.0413
# Epoch 18/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0030 - mae: 0.0403
# Epoch 19/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0029 - mae: 0.0400
# Epoch 20/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0028 - mae: 0.0385
# Epoch 21/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0027 - mae: 0.0391
# Epoch 22/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0027 - mae: 0.0381
# Epoch 23/30
# 250/250 [==============================] - 12s 47ms/step - loss: 0.0028 - mae: 0.0385
# Epoch 24/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0027 - mae: 0.0379
# Epoch 25/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0026 - mae: 0.0376
# Epoch 26/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0026 - mae: 0.0372
# Epoch 27/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0026 - mae: 0.0373
# Epoch 28/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0024 - mae: 0.0359
# Epoch 29/30
# 250/250 [==============================] - 13s 53ms/step - loss: 0.0023 - mae: 0.0354
# Epoch 30/30
# 250/250 [==============================] - 13s 52ms/step - loss: 0.0025 - mae: 0.0361

# %%
import matplotlib.pyplot as plt
myloss = model.history.history['loss']
plt.plot(range(len(myloss)), model.history.history['loss'])

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
# tratrainPredict = scaler.inverse_transform(trainPredict)
#train값과 test값 예측
trainPredict = model.predict(x_train)
testPredict = model.predict(x_test)

# 역정규화 과정
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([y_test])

# rmse 계산
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# 250/250 [==============================] - 2s 6ms/step
# 23/23 [==============================] - 0s 8ms/step
# Train Score: 732.24 RMSE
# Test Score: 926.42 RMSE

# %%
val_train  = pd.DataFrame() #예측값 검증을 위한 df 생성

trainPredict = pd.DataFrame(trainPredict)
trainPredict.index = train[-len(trainPredict):].index #실제 test 범위에 해당하는 index 매칭

val_train['actual'] = train[-len(trainPredict):] #실제 값 할당
val_train['prediction'] = trainPredict #예측한 값 할당

val_train.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
len(val_train)
# Out:
# 7992

# %%
val_test = pd.DataFrame() #예측값 검증을 위한 df 생성

testPredict = pd.DataFrame(testPredict)
testPredict.index = test[-len(testPredict):].index #실제 test 범위에 해당하는 index 매칭

val_test['actual'] = test[-len(testPredict):] #실제 값 할당
val_test['prediction'] = testPredict #예측한 값 할당

val_test.plot()
# Out:
# <Axes: xlabel='Datetime'>

# %%
from keras.models import load_model
model.save("jingwan_model.h5")
